# %%
import MakeVideoFromImages as makeVideo

# %%
video = makeVideo.MakeVideoFromImages("./sample")
#video.setVideoSize(300,200)
#video.setOutputName("sample")
video.makeVideo()
# Out:
# CARDS_COURTYARD_B_T_frame_0113.jpg
# CARDS_COURTYARD_B_T_frame_0183.jpg
# CARDS_COURTYARD_B_T_frame_0184.jpg
# CARDS_COURTYARD_B_T_frame_0611.jpg
# CARDS_COURTYARD_B_T_frame_0815.jpg
# CARDS_COURTYARD_B_T_frame_1024.jpg
# CARDS_COURTYARD_B_T_frame_1344.jpg
# CARDS_COURTYARD_B_T_frame_1362.jpg
# CARDS_COURTYARD_B_T_frame_1379.jpg
# CARDS_COURTYARD_B_T_frame_2208.jpg
# CARDS_COURTYARD_B_T_frame_2363.jpg
# CARDS_COURTYARD_B_T_frame_2429.jpg
# CARDS_COURTYARD_H_S_frame_0549.jpg
# CARDS_COURTYARD_H_S_frame_1021.jpg
# CARDS_COURTYARD_H_S_frame_1036.jpg
# CARDS_COURTYARD_H_S_frame_1115.jpg
# CARDS_COURTYARD_H_S_frame_1530.jpg
# CARDS_COURTYARD_H_S_frame_1660.jpg
# CARDS_COURTYARD_H_S_frame_1680.jpg
# CARDS_COURTYARD_H_S_frame_1962.jpg
# CARDS_COURTYARD_H_S_frame_2134.jpg
# CARDS_COURTYARD_H_S_frame_2387.jpg
# CARDS_COURTYARD_S_H_frame_0093.jpg
# CARDS_COURTYARD_S_H_frame_1218.jpg
# CARDS_COURTYARD_S_H_frame_1343.jpg
# CARDS_COURTYARD_S_H_frame_1353.jpg
# CARDS_COURTYARD_S_H_frame_2464.jpg
# ...
